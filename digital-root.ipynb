# %%
 # Write a python program to find the digital root of a number. 
try:
    num = int(input("Enter your number:"))
    while num >= 10:
        num = sum(int(x) for x in str(num))
    print("Digital Root:", num)
except ValueError:
    print("Error: Invalid input")
# Out:
# Enter your number: 21212
# Digital Root: 8
