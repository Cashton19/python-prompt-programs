# %%
numbers = [10, -3, 25, 50, -7, 75, 100, 200, 300]
for number in numbers:
    if number < 0:
        continue
    elif number == 100:
        break
    print(number, end = ", ")
# Out:
# 10, 25, 50, 75,
