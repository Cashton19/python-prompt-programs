# %%
try:
    while True:
        number = int(input("Enter Zero:")) 
        if number != 0:
            print("Please enter zero to break the loop")
        else:
            print("You have sucessfully broken the loop")
            break          
except ValueError:
    print("Error: Invalid Input!!")
# Out:
# Enter Zero: 212
# Please enter zero to break the loop
# Enter Zero: 0
# You have sucessfully broken the loop
